# %% [markdown]
# Q1: Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats
import math

sample_mean = 50
sample_std = 5
sample_size = 100
confidence_level = 0.95

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=sample_std/math.sqrt(sample_size))
print(f"95% Confidence Interval: {confidence_interval}")
# Out:
# 95% Confidence Interval: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# Interpretation:
#
# We are 95% confident that the true population mean falls within the range of [48.58, 51.42] based on the given sample

# %% [markdown]
# Q2: Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.

# %%
import numpy as np
from scipy.stats import chisquare

observed_counts = [18, 22, 19, 9, 11, 21]  # Replace with actual counts for each color
expected_counts = [20, 20, 20, 10, 10, 20]

chi2_stat, p_value = chisquare(f_obs=observed_counts, f_exp=expected_counts)

print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("Reject the null hypothesis. The distribution of M&M colors is significantly different from the expected distribution.")
else:
    print("Fail to reject the null hypothesis. The distribution of M&M colors is consistent with the expected distribution.")
# Out:
# Chi-square statistic: 0.7000000000000001
# P-value: 0.9829686751880324
# Fail to reject the null hypothesis. The distribution of M&M colors is consistent with the expected distribution.

# %% [markdown]
# Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:

# %% [markdown]
# ![image.png](attachment:34d19f2e-6b68-4cca-a921-357e6292e662.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Create the contingency table
data = np.array([[20, 15],
                 [10, 25],
                 [15, 20]])

# Perform the chi-square test
chi2_stat, p_value, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("Reject the null hypothesis. There is a significant association between groups and outcomes.")
else:
    print("Fail to reject the null hypothesis. The association between groups and outcomes is not significant.")
# Out:
# Chi-square statistic: 5.833333333333334
# P-value: 0.05411376622282158
# Fail to reject the null hypothesis. The association between groups and outcomes is not significant.

# %% [markdown]
# interpretation:
#
# The chi-square statistic is a measure of the difference between the observed and expected frequencies in the contingency table.
# The p-value is used to determine the statistical significance of the test.
# If the p-value is less than 0.05, you would reject the null hypothesis, indicating that there is a significant association between groups and outcomes.
# If the p-value is greater than 0.05, you would fail to reject the null hypothesis, suggesting that the association is not significant.
# Please note that this interpretation assumes a significance level of 0.05. You can adjust the significance level based on your specific requirements.

# %% [markdown]
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
import statsmodels.api as sm

sample_size = 500
smokers = 60
confidence_level = 0.95

confidence_interval = sm.stats.proportion_confint(smokers, sample_size, alpha=1-confidence_level)
print(f"95% Confidence Interval for Smoking Prevalence: {confidence_interval}")
# Out:
# 95% Confidence Interval for Smoking Prevalence: (0.09151638887130707, 0.1484836111286929)

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats
import math
sample_mean = 75
sample_std = 12
sample_size = 100
confidence_level = 0.90

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=sample_std/math.sqrt(sample_size))
print(f"90% Confidence Interval: {confidence_interval}")
# Out:
# 90% Confidence Interval: (73.02617564765823, 76.97382435234177)

# %% [markdown]
# Interpretation:
#
# We are 90% confident that the true population mean falls within the range of [72.98, 77.02] based on the given sample.

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

df = 10  # degrees of freedom
chi_square_stat = 15

x = np.linspace(0, 30, 1000)
y = stats.chi2.pdf(x, df)

plt.plot(x, y, label=f"Chi-square Distribution (df={df})")
plt.fill_between(x, y, where=(x >= chi_square_stat), color='red', alpha=0.3, label=f"Shaded Area (stat={chi_square_stat})")

plt.title("Chi-square Distribution")
plt.xlabel("Chi-square Statistic")
plt.ylabel("Probability Density Function")
plt.legend()
plt.show()

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.

# %%
import statsmodels.api as sm

sample_size = 1000
coke_preferred = 520
confidence_level = 0.99

confidence_interval = sm.stats.proportion_confint(coke_preferred, sample_size, alpha=1-confidence_level)
print(f"99% Confidence Interval for Coke Preference: {confidence_interval}")
# Out:
# 99% Confidence Interval for Coke Preference: (0.4793051576779699, 0.5606948423220302)

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
import numpy as np
from scipy.stats import chisquare

observed_freq = np.array([45, 55])  # tails, heads
expected_freq = np.array([50, 50])  # fair coin

chi2_stat, p_value = chisquare(f_obs=observed_freq, f_exp=expected_freq)

print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("Reject the null hypothesis. The coin is significantly biased towards tails.")
else:
    print("Fail to reject the null hypothesis. The coin is not significantly biased.")
# Out:
# Chi-square statistic: 1.0
# P-value: 0.31731050786291115
# Fail to reject the null hypothesis. The coin is not significantly biased.

# %% [markdown]
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.

# %% [markdown]
# ![image.png](attachment:7d622139-0759-4638-9477-2ce7dddabd7c.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Create the contingency table
data = np.array([[60, 140],
                 [30, 170]])

# Perform the chi-square test for independence
chi2_stat, p_value, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")

alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between smoking status and lung cancer diagnosis.")
# Out:
# Chi-square statistic: 12.057347670250895
# P-value: 0.0005158863863703744
# Reject the null hypothesis. There is a significant association between smoking status and lung cancer diagnosis.

# %% [markdown]
# Interpretation:
#
# The chi-square statistic is a measure of the difference between the observed and expected frequencies in the contingency table.
# The p-value is used to determine the statistical significance of the test.
# If the p-value is less than 0.05 (or your chosen significance level), you would reject the null hypothesis, indicating that there is a significant association between smoking status and lung cancer diagnosis.
# If the p-value is greater than 0.05, you would fail to reject the null hypothesis, suggesting that there is no significant association.
# This analysis assumes a significance level of 0.05. You can adjust the significance level based on your specific requirements.

# %% [markdown]
# Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin.

# %% [markdown]
# ![image.png](attachment:9afa0e31-928a-4cca-b14c-2448f2995dbb.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Create the contingency table
data = np.array([[200, 150, 150],
                 [225, 175, 100]])

# Perform the chi-square test for independence
chi2_stat, p_value, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")

alpha = 0.01

if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between chocolate preference and country of origin.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between chocolate preference and country of origin.")
# Out:
# Chi-square statistic: 13.393665158371041
# P-value: 0.0012348168997745918
# Reject the null hypothesis. There is a significant association between chocolate preference and country of origin.

# %% [markdown]
# Interpretation:
#
# The chi-square statistic is a measure of the difference between the observed and expected frequencies in the contingency table.
# The p-value is used to determine the statistical significance of the test.
# If the p-value is less than 0.01 (or your chosen significance level), you would reject the null hypothesis, indicating that there is a significant association between chocolate preference and country of origin.
# If the p-value is greater than 0.01, you would fail to reject the null hypothesis, suggesting that there is no significant association.
# This analysis assumes a significance level of 0.01. You can adjust the significance level based on your specific requirements.

# %% [markdown]
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

# %%
import scipy.stats as stats

# Given data
sample_mean = 72
sample_std = 10
sample_size = 30
population_mean_hypothesized = 70
significance_level = 0.05

# Calculate the t-statistic
t_statistic = (sample_mean - population_mean_hypothesized) / (sample_std / (sample_size**0.5))

# Degrees of freedom for a t-distribution with n-1 degrees of freedom
degrees_of_freedom = sample_size - 1

# Calculate the p-value for a two-tailed test
p_value = 2 * (1 - stats.t.cdf(abs(t_statistic), df=degrees_of_freedom))

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Compare the p-value to the significance level
if p_value < significance_level:
    print("Reject the null hypothesis. The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis. There is not enough evidence to suggest a significant difference.")
# Out:
# T-statistic: 1.0954451150103321
# P-value: 0.2823362372860698
# Fail to reject the null hypothesis. There is not enough evidence to suggest a significant difference.

# %% [markdown]
# Interpretation:
#
# The t-statistic measures how many standard errors the sample mean is from the hypothesized population mean.
# The p-value is used to determine the statistical significance of the test.
# If the p-value is less than 0.05 (or your chosen significance level), you would reject the null hypothesis, indicating that the population mean is significantly different from 70.
# If the p-value is greater than 0.05, you would fail to reject the null hypothesis, suggesting that there is not enough evidence to conclude a significant difference.
# This analysis assumes a two-tailed test (checking for differences in both directions). You can adjust the test based on the specific nature of your hypothesis.
