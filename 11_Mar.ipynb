# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would use each type of test.
# ![image.png](attachment:c2123e92-c30a-48bc-9a9c-c9d4479400bb.png) of students.

# %% [markdown]
# Q2: Differentiate between one-tailed and two-tailed tests.
#
# One-Tailed Test:
#
# Examines whether a parameter is greater than or less than a specified value.
# Example: Testing if a new drug increases (one-tailed greater) or decreases (one-tailed less) blood pres
# sure.
# Two-Tailed Test:
#
# Examines whether a parameter is different from a specified value in either direction.
# Example: Testing if a coin is biased (two-tailed) rather than specifically testing for heads or tails.or tails.

# %% [markdown]
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for each type of error.
#
# Type 1 Error (False Positive):
#
# Incorrectly rejecting a true null hypothesis.
# Example: Concluding a person is guilty when they are innocent (legal context).
# Type 2 Error (False Negative):
#
# Failing to reject a false null hypothesis.
# Example: Concluding a person is innocent when they are guilty (legal context).

# %% [markdown]
# Q4: Explain Bayes's theorem with an example.
#
# ![image.png](attachment:1a4c4731-bae2-46a1-8392-c7383891dd3f.png)

# %% [markdown]
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.
#
# ![image.png](attachment:57d931d4-5fb3-4b5c-aede-9a68d17215a5.png)of 2 pounds.of 2 pounds.

# %% [markdown]
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the event's probability and new evidence. Provide a sample problem and solution.
# Example Problem:
#
# A factory produces light bulbs, and 2% of the bulbs are defective. A quality control test detects 95% of defective bulbs. What is the probability that a bulb is defective given that it failed the test?g)tion:

# %% [markdown]
# ![image.png](attachment:844a78e1-42c7-4b1d-af25-0c14a7dbc47c.png)

# %% [markdown]
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5. Interpret the results.

# %%
import scipy.stats as stats
import math

sample_mean = 50
sample_std = 5
sample_size = 100
confidence_level = 0.95

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=sample_std/math.sqrt(sample_size))
print(f"95% Confidence Interval: {confidence_interval}")
# Out:
# 95% Confidence Interval: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# Interpretation:
#
# We are 95% confident that the true population mean falls within the range of [48.58, 51.42] based on the given sample.

# %% [markdown]
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error? Provide an example of a scenario where a larger sample size would result in a smaller margin of error.
#
# Margin of Error:
#
# It is the range within which we expect the true population parameter to lie.
# Effect of Sample Size:
#
# A larger sample size decreases the standard error and, consequently, the margin of error.
# Example:
#
# A survey estimates the average income of a city with a sample of 1000 residents and a margin of error of $500. If the survey had used a sample of 5000 residents, the margin of error might have been reduced to $200.

# %% [markdown]
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population standard deviation of 5. Interpret the results.

# %%
z_score = (75 - 70) / 5
print(f"Z-Score: {z_score}")
# Out:
# Z-Score: 1.0

# %% [markdown]
# Interpretation:
#
# The data point of 75 is 1 standard deviation above the mean in the given population.

# %% [markdown]
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is significantly effective at a 95% confidence level using a t-test.

# %%
import scipy.stats as stats

sample_mean = 6
sample_std = 2.5
sample_size = 50
confidence_level = 0.95

t_statistic, p_value = stats.ttest_1samp([sample_mean]*sample_size, popmean=0)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

if p_value < (1 - confidence_level)/2 or p_value > 1 - (1 - confidence_level)/2:
    print("Reject the null hypothesis. The drug is significantly effective.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# T-statistic: inf, P-value: 0.0
# Reject the null hypothesis. The drug is significantly effective.
# C:\Users\swast\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95% confidence interval for the true proportion of people who are satisfied with their job.

# %%
import statsmodels.api as sm

sample_proportion = 0.65
sample_size = 500
confidence_level = 0.95

conf_interval = sm.stats.proportion_confint(sample_proportion * sample_size, sample_size)
print(f"95% Confidence Interval: {conf_interval}")
# Out:
# 95% Confidence Interval: (0.6081925393809212, 0.6918074606190788)

# %% [markdown]
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance. Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82 with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a significant difference in student performance using a t-test with a significance level of 0.01.

# %%
import scipy.stats as stats

sample_mean_A = 85
sample_std_A = 6
sample_size_A = 30

sample_mean_B = 82
sample_std_B = 5
sample_size_B = 30

significance_level = 0.01

t_statistic, p_value = stats.ttest_ind_from_stats(mean1=sample_mean_A, std1=sample_std_A, nobs1=sample_size_A,
                                                  mean2=sample_mean_B, std2=sample_std_B, nobs2=sample_size_B,
                                                  equal_var=False)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

if p_value < significance_level:
    print("Reject the null hypothesis. There is a significant difference in performance between the two teaching methods.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# T-statistic: 2.1038606199548298, P-value: 0.03987998118234142
# Fail to reject the null hypothesis.

# %% [markdown]
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean of 65. Calculate the 90% confidence interval for the true population mean.

# %%
import scipy.stats as stats

population_mean = 60
population_std = 8
sample_mean = 65
sample_size = 50
confidence_level = 0.90

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=population_std/math.sqrt(sample_size))
print(f"90% Confidence Interval: {confidence_interval}")
# Out:
# 90% Confidence Interval: (63.13906055411732, 66.86093944588268)

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to determine if caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %%
import scipy.stats as stats

sample_mean = 0.25
sample_std = 0.05
sample_size = 30
confidence_level = 0.90

t_statistic, p_value = stats.ttest_1samp([sample_mean]*sample_size, popmean=0)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

if p_value < (1 - confidence_level)/2 or p_value > 1 - (1 - confidence_level)/2:
    print("Reject the null hypothesis. Caffeine has a significant effect on reaction time.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# T-statistic: inf, P-value: 0.0
# Reject the null hypothesis. Caffeine has a significant effect on reaction time.
# C:\Users\swast\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
