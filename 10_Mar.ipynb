# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
#
# Estimation Statistics: It involves using sample data to make inferences about the population parameters. Estimation provides a range of plausible values for an unknown parameter.
#
# Point Estimate: A single value that is used to estimate a population parameter. For example, the sample mean is a point estimate of the population mean.
#
# Interval Estimate: A range of values that is likely to contain the true value of the population parameter. It is expressed as a confidence interval. For instance, a 95% confidence interval for the population mean provides a range of values within which we are 95% confident the true mean lies.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
import math

def confidence_interval(sample_mean, sample_std, sample_size, confidence_level):
    z_critical = abs(stats.norm.ppf((1 - confidence_level) / 2))
    margin_of_error = z_critical * (sample_std / math.sqrt(sample_size))
    
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    
    return lower_bound, upper_bound

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
#
# Hypothesis Testing: It is a statistical method used to make inferences about population parameters based on sample data. It involves formulating a hypothesis, collecting and analyzing data, and drawing conclusions.
#
# Importance: Hypothesis testing allows researchers to make informed decisions about population parameters. It helps determine whether observed effects are statistically significant or merely due to random chance.

# %% [markdown]
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
#
# Hypothesis:
# Null Hypothes(
# H
# 0
# ​
#  ): The average weight of male college students is equal to or less than the average weight of female college students.
# Alternative  (
# �
# �
# H
# a
# ​
#  ): The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import scipy.stats as stats

def two_sample_t_test(sample1, sample2):
    t_stat, p_value = stats.ttest_ind(sample1, sample2, equal_var=False)
    return t_stat, p_value

# Example usage:
sample_male = [72, 75, 78, 70, 74]
sample_female = [65, 68, 72, 69, 71]
t_statistic, p_value = two_sample_t_test(sample_male, sample_female)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")
# Out:
# T-statistic: 2.6264431447899956, P-value: 0.030612851040411473

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# ![image.png](attachment:662f84bd-0468-45fa-8bfa-ecd1d9c4405c.png)

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# ![image.png](attachment:b15ce684-a71d-4e27-80ed-1d8546104471.png)

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.
#
# P-value: It is the probability of observing a test statistic as extreme as, or more extreme than, the one observed, assuming the null hypothesis is true.
#
# Significance: A small p-value (typically less than 0.05) provides evidence to reject the null hypothesis. It indicates that the observed data is unlikely under the assumption that the null hypothesis is true.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

degrees_of_freedom = 10
x = np.linspace(-3, 3, 1000)
y = stats.t.pdf(x, df=degrees_of_freedom)

plt.plot(x, y, label=f't-Distribution (df={degrees_of_freedom})')
plt.title('Student\'s t-Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density Function (PDF)')
plt.legend()
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import scipy.stats as stats

def two_sample_t_test(sample1, sample2):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    return t_stat, p_value

# Example usage:
sample1 = [25, 30, 35, 40, 45]
sample2 = [20, 28, 32, 38, 42]
t_statistic, p_value = two_sample_t_test(sample1, sample2)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")
# Out:
# T-statistic: 0.5741692517632145, P-value: 0.5816333668955778

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.
#
# Student's t-Distribution: It is a probability distribution used in hypothesis testing when the sample size is small or when the population standard deviation is unknown.
#
# When to Use: The t-distribution is used when dealing with small sample sizes and estimating the population standard deviation from the sample.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# ![image.png](attachment:4527bea9-3eb8-40f1-9f19-74364b43c103.png)

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be  $500 with a standard deviation of  $50. Estimate the population mean revenue with a 95% confidence interval.

# %%
import scipy.stats as stats

sample_mean = 500
sample_std = 50
sample_size = 50
confidence_level = 0.95

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=sample_std/math.sqrt(sample_size))
print(f"95% Confidence Interval: {confidence_interval}")
# Out:
# 95% Confidence Interval: (486.1409617565032, 513.8590382434968)

# %% [markdown]
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %%
import scipy.stats as stats

population_mean_hypothesized = 10
sample_mean = 8
sample_std = 3
sample_size = 100
significance_level = 0.05

t_statistic, p_value = stats.ttest_1samp([sample_mean]*sample_size, population_mean_hypothesized)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

if p_value < significance_level:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# T-statistic: -inf, P-value: 0.0
# Reject the null hypothesis.
# C:\Users\swast\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %%
import scipy.stats as stats

population_mean_hypothesized = 5
sample_mean = 4.8
sample_std = 0.5
sample_size = 25
significance_level = 0.01

t_statistic, p_value = stats.ttest_1samp([sample_mean]*sample_size, population_mean_hypothesized)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

if p_value < significance_level:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# T-statistic: -inf, P-value: 0.0
# Reject the null hypothesis.

# %% [markdown]
# ![image.png](attachment:7b780706-85d7-42f8-a204-df2c6a558cbc.png)

# %%
import scipy.stats as stats

sample_mean1 = 80
sample_std1 = 10
sample_size1 = 30

sample_mean2 = 75
sample_std2 = 8
sample_size2 = 40

significance_level = 0.01

t_statistic, p_value = stats.ttest_ind_from_stats(mean1=sample_mean1, std1=sample_std1, nobs1=sample_size1,
                                                  mean2=sample_mean2, std2=sample_std2, nobs2=sample_size2,
                                                  equal_var=False)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

if p_value < significance_level:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# T-statistic: 2.2511258444537408, P-value: 0.02845213338800089
# Fail to reject the null hypothesis.

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
import scipy.stats as stats

sample_mean = 4
sample_std = 1.5
sample_size = 50
confidence_level = 0.99

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=sample_std/math.sqrt(sample_size))
print(f"99% Confidence Interval: {confidence_interval}")
# Out:
# 99% Confidence Interval: (3.4535840896844654, 4.546415910315535)
